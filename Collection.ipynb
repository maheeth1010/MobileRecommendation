# %% [markdown]
# # Main interest of this notebook is Collection of data!
# ### This is the first notebook created for the project 😉

# %% [markdown]
# # Wherever there is involvement of beautiful soup, be careful and inspect the page and the element you are scraping to remove errors.

# %%
pip install --upgrade pip
# Out:
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.2
#     Uninstalling pip-20.2.2:
#       Successfully uninstalled pip-20.2.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install future
# Out:
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491061 sha256=b0c844f3827670bc6b7550a143c8fb878d4ab45806cb84375de5dc775daea891
#   Stored in directory: c:\users\nagen\appdata\local\pip\cache\wheels\56\b0\fe\4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gspread
# Out:
# ...
#   Using cached gspread-3.6.0-py3-none-any.whl (26 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install oauth2client
# Out:
# ...
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## These are the features we selected for extraction from the website.

# %%
attr = [
    "Brand","Model","Released","Manufacturer","OEM ID",
    
    "Width","Height","Depth","Mass",
    
    "Platform"
,"Operating System"
,"Software Extras",
    
  "CPU Clock"
,"CPU",  
    
   "RAM Type"
,"RAM Capacity (converted)",
    
    "Non-volatile Memory Type"
,"Non-volatile Memory Capacity (converted)",
    
    "Display Diagonal"
,"Resolution"
,"Display Area"
,"Pixel Size"
,"Pixel Density"
,"Display Type",
    
    "Graphical Controller"
,"GPU Clock:",
    
    "A/V Out"
,"A/V Out Max. Resolution",
    
    "Audio Channel(s)",
    
    "Microphone(s)",
    
    "D/A Converter Nominal Resolution"
,"D/A Holding Frequency"
,"Loudpeaker(s):"
,"Audio Output:",
    
    "Supported Cellular Bands"
,"Supported Cellular Data Links"
,"SIM Card Slot"
,"Call Alert Sound"
,"Hearing Aid Compatibility (HAC)"
,"Cellular Controller",
    
    "Dual Cellular Network Operation"
,"Sec. SIM Card Slot",
    
    "Touchscreen Type"
,"Touchscreen Simultaneous Touch Points",
    
    "Expansion Interfaces"
,"USB"
,"USB Services"
,"USB Connector"
,"Max. Charging Power:",
    
    "Bluetooth profiles",
    
    "Wireless Services",
    
    "FM Radio Receiver",
    
    "Supported GPS protocol(s)",
    
    "Camera Placement"
,"Camera Image Sensor"
,"Image Sensor Pixel Size"
,"Camera Resolution"
,"Number of effective pixels"
,"Aperture (W)"
,"Zoom"
,"Focus"
,"Recordable Image Formats"
,"Video Recording"
,"Recordable Video Formats"
,"Flash"
,"Camera Extra Functions",
    
    "Aux. Camera Image Sensor"
,"Aux. Cam. Image Sensor Pixel Size"
,"Auxiliary Camera Resolution",
    
    "Secondary Camera Placement"
,"Secondary Camera Sensor"
,"Secondary Image Sensor Pixel Size"
,"Secondary Camera Resolution"
,"Secondary Number of pixels",
    
    "Built-in compass"
,"Built-in accelerometer"
,"Built-in gyroscope"
,"Additional sensors",
    
    "Protection from solid materials"
,"Protection from liquids",
    
    "Battery"
,"Battery Cells in Parallel"
,"Nominal Battery Voltage"
,"Nominal Battery Capacity"
,"Nominal Battery Energy"
,"Estimated Battery Life"
,"Talk Time:"
,"Wireless Charging",
    
    "Market Countries",
    "Price"
]

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 20)

# %%
new = pd.DataFrame(columns=attr) # set empty df columns to match

# %% [markdown]
# ## The following is to get all the filters and pages for a specific mobile.

# %% [markdown]
# ### Samsung

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
   
URL = "http://phonedb.net/index.php?m=device&s=list&first=samsung"

r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 
contentpages=[] 
#allLinks = soup.find_all('div', attrs = {'class':'compact_list_item'})
links = soup.find_all('div', attrs = {'class':'container'})
#links = soup.find_all('b')

#for row in allLinks:
for link in links[-2].find_all('a'):
    fullLink = link.get ('href')
    contentpages.append(fullLink)

cpages = []
for i in contentpages:
    i = 'http://phonedb.net/'+i
    cpages.append(i)

# %% [markdown]
# ### Oppo

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
   
URL = "http://phonedb.net/index.php?m=device&s=list&first=motorola"

r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 
contentpages=[] 
#allLinks = soup.find_all('div', attrs = {'class':'compact_list_item'})
links = soup.find_all('div', attrs = {'class':'container'})
#links = soup.find_all('b')

#for row in allLinks:
for link in links[-2].find_all('a'):
    fullLink = link.get ('href')
    contentpages.append(fullLink)

cpages = []
for i in contentpages:
    i = 'http://phonedb.net'+i
    cpages.append(i)

# %%
cpages
# Out:
# ['http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=0',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=29',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=58',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=87',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=116',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=145',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=174',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=203',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=232',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=261',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=290',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=319',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=348',
# ...

# %%
oppopages = []
for i in cpages:
    if i.find('/index.php?m=device&s=list&first=motorola&filter')!=-1 and i not in oppopages:
        oppopages.append(i)

# %%
oppopages
# Out:
# ['http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=0',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=29',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=58',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=87',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=116',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=145',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=174',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=203',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=232',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=261',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=290',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=319',
#  'http://phonedb.net/index.php?m=device&s=list&first=motorola&filter=348',
# ...

# %% [markdown]
# ## converting the above links to "http://phonedb.net/" format

# %%
oppowebs = []
for i in oppopages:
    newlink = "http://phonedb.net"+i
    oppowebs.append(newlink)

# %%
oppopages
# Out:
# ['http://phonedb.net/index.php?m=device&s=list&first=asus&filter=0',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=29',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=58',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=87',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=116',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=145',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=174',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=203',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=232',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=261',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=290',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=319',
#  'http://phonedb.net/index.php?m=device&s=list&first=asus&filter=348',
# ...

# %% [markdown]
# ## Now getting mobiles from every page (links of mobiles)

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
   
contentpages = []

# looping urls
for url in oppopages:
    r = requests.get(url) 

    soup = BeautifulSoup(r.content, 'html5lib') 
    
    # every link of a mobile is residing in a content_block_title, so getting that link
    links = soup.find_all('div', attrs = {'class':'content_block_title'})

    for row in links:
        for link in row.find_all('a'):
            fullLink = link.get ('href')
            fullLink = "http://phonedb.net/"+fullLink
            contentpages.append(fullLink)

# %%
contentpages
# Out:
# ['http://phonedb.net/index.php?m=device&id=17445&c=motorola_moto_g9_play_2020_lte-a_latam_64gb_xt2083-1__motorola_guamp',
#  'http://phonedb.net/index.php?m=device&id=17444&c=motorola_moto_g9_play_2020_dual_sim_lte-a_latam_64gb_xt2083-1__moto_g9__motorola_guamp',
#  'http://phonedb.net/index.php?m=device&id=17443&c=motorola_moto_g9_plus_2020_global_dual_sim_lte-a_xt2087-2__motorola_odessa',
#  'http://phonedb.net/index.php?m=device&id=17442&c=motorola_moto_g9_plus_2020_latam_lte-a_xt2087-1__motorola_odessa',
#  'http://phonedb.net/index.php?m=device&id=17438&c=motorola_moto_e7_plus_2020_dual_sim_lte-a_latam_xt2081-1__motorola_guam',
#  'http://phonedb.net/index.php?m=device&id=17431&c=motorola_moto_g9_plus_2020_dual_sim_latam_lte-a_xt2087-1__motorola_odessa',
#  'http://phonedb.net/index.php?m=device&id=17401&c=motorola_moto_one_5g_td-lte_128gb_xt2075-1__xt2075-2__motorola_nairobi',
# ...

# %%
oppopages = []
for i in contentpages:
    if i.find('iphone')!=-1:
        oppopages.append(i)

# %%
oppopages
# Out:
# ['http://phonedb.net/index.php?m=device&id=17560&c=apple_iphone_12_pro_max_5g_a2411_global_dual_sim_td-lte_512gb__apple_iphone_13,4',
#  'http://phonedb.net/index.php?m=device&id=16895&c=apple_iphone_se_2020_2nd_gen_a2296_global_dual_sim_td-lte_128gb__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16896&c=apple_iphone_se_2020_2nd_gen_a2296_global_dual_sim_td-lte_256gb__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16894&c=apple_iphone_se_2020_2nd_gen_a2298_td-lte_cn_256gb__a2297__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16893&c=apple_iphone_se_2020_2nd_gen_a2298_td-lte_cn_128gb__a2297__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16889&c=apple_iphone_se_2020_2nd_gen_a2298_td-lte_cn_64gb__a2297__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16888&c=apple_iphone_se_2020_2nd_gen_a2296_global_dual_sim_td-lte_64gb__apple_iphone_12,8',
# ...

# %%
contentpages = oppopages
contentpages
# Out:
# ['http://phonedb.net/index.php?m=device&id=17560&c=apple_iphone_12_pro_max_5g_a2411_global_dual_sim_td-lte_512gb__apple_iphone_13,4',
#  'http://phonedb.net/index.php?m=device&id=16895&c=apple_iphone_se_2020_2nd_gen_a2296_global_dual_sim_td-lte_128gb__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16896&c=apple_iphone_se_2020_2nd_gen_a2296_global_dual_sim_td-lte_256gb__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16894&c=apple_iphone_se_2020_2nd_gen_a2298_td-lte_cn_256gb__a2297__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16893&c=apple_iphone_se_2020_2nd_gen_a2298_td-lte_cn_128gb__a2297__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16889&c=apple_iphone_se_2020_2nd_gen_a2298_td-lte_cn_64gb__a2297__apple_iphone_12,8',
#  'http://phonedb.net/index.php?m=device&id=16888&c=apple_iphone_se_2020_2nd_gen_a2296_global_dual_sim_td-lte_64gb__apple_iphone_12,8',
# ...

# %%
len(contentpages)
# Out:
# 638

# %% [markdown]
# ## We finally got the links of every mobile, now we'll extract the features of every mobile from its link
# # This is a time consuming process.. BE PATIENT

# %%
import re
string_lst = ['Platform', 'jkg', 'sun', 'gum']
x="Platform:"

print(re.findall(r"(?=("+'|'.join(string_lst)+r"))",x))

'''else:
                names = re.findall(r"(?=("+'|'.join(attr)+r"))",name)
                if names!=[]:
                    print(name)
                    print(names)
                    ll[names[0]]=field'''
# Out:
# ['Platform']

# %% [markdown]
# ### This is just for testing on "Currency"

# %%
from bs4 import BeautifulSoup
import csv
import requests 

specs = []
cpages = contentpages[301:400]
# url = "http://phonedb.net/index.php?m=device&id=17331&c=asus_rog_phone_3_5g_strix_edition_global_dual_sim_td-lte_version_b_128gb_zs661ks__asus_i003d"

for rii in cpages:
    r = requests.get(rii) 
    soup = BeautifulSoup(r.content, 'html5lib')
    trs = soup.find_all('tr')
    count = 0
    ll = {}
    for tr in trs:
        tds = tr.find_all('td')
        if len(tds)>=2:
            name = tds[0].get_text()
            field = tds[1].get_text().strip()
            name = name.strip()
            if name=="Price":
                index = trs.index(tr)
                nextTr = trs[index+1]
                nextTd = nextTr.find_all('td')
                ll[name]=field+nextTd[1].get_text().strip()
            elif name in attr:
                ll[name]=field
    specs.append(ll)

# %%
len(specs)
#strings_with_substring
#specs
# Out:
# 99

# %% [markdown]
# ## Now we will convert the dictionary into a pandas dataframe

# %%
speclist = list(specs)
temp = pd.DataFrame(columns=attr)
temp = temp.append(speclist, ignore_index = True, sort = False)

# %%
temp.shape
# Out:
# (99, 90)

# %%
new = new.append(temp, ignore_index = True, sort = False)
new = pd.DataFrame.drop_duplicates(new)
new
# Out:
#     Brand                Model     Released      Manufacturer  \
# 0    Asus  ZenFone 3 Deluxe...   2016 Sep 9  ASUSTeK Computer
# 1    Asus  ZenFone 3 Ultra ...     2016 Oct  ASUSTeK Computer
# 2    Asus  ZenFone Max Dual...  2016 May 28  ASUSTeK Computer
# 3    Asus  ZenFone Max Dual...  2016 May 28  ASUSTeK Computer
# 4    Asus  ZenFone Go TV Du...  2016 May 21  ASUSTeK Computer
# 5    Asus  ZenFone Go TV Du...  2016 May 17  ASUSTeK Computer
# 6    Asus  ZenFone Go TV Du...  2016 May 23  ASUSTeK Computer
# 7    Asus  ZenFone 3 Dual S...     2016 Jul  ASUSTeK Computer
# 8    Asus  ZenFone 2 Laser ...     2016 May  ASUSTeK Computer
# 9    Asus  ZenFone Max Dual...  2016 Jan 14  ASUSTeK Computer
# 10   Asus  ZenFone Go Dual ...  2016 Mar 29  ASUSTeK Computer
# 11   Asus  ZenFone 2 Deluxe...     2016 Apr  ASUSTeK Computer
# 12   Asus  ZenFone 2 Laser ...     2015 Nov  ASUSTeK Computer
# 13   Asus  ZenFone 2 Laser ...     2015 Nov  ASUSTeK Computer
# ...

# %% [markdown]
# ## Now pushing the dataframe to Google sheets

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
def iter_pd(df):
    for val in df.columns:
        yield val
    for row in df.to_numpy():
        for val in row:
            if pd.isna(val):
                yield ""
            else:
                yield val

def pandas_to_sheets(pandas_df, sheet, clear = False):
    if clear:
        sheet.clear()
    (row, col) = pandas_df.shape
    cells = sheet.range("A1:{}".format(gspread.utils.rowcol_to_a1(row + 1, col)))
    for cell, val in zip(cells, iter_pd(pandas_df)):
        cell.value = val
    sheet.update_cells(cells)

scope =  ['https://www.googleapis.com/auth/spreadsheets', "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)
sheet = client.open("testing_sheets").sheet1    
pandas_to_sheets(temp,sheet)

# %% [markdown]
# ## This process is for GSMArena

# %% [markdown]
# ### Extracting Phone brands

# %%
import requests 
from bs4 import BeautifulSoup 
import csv

url = "https://www.gsmarena.com/xiaomi_redmi_note_5_pro-8893.php"
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
phones = soup.find_all('div',attrs={'class':'brandmenu-v2 light l-box clearfix'})
brands = []
for phone in phones:
    unord = phone.find('ul')
    for order in unord.find_all('li'):
        link = order.find('a').get('href')
        fullLink = "https://www.gsmarena.com/"+link
        brands.append(fullLink)
brands
# Out:
# ['https://www.gsmarena.com/samsung-phones-9.php',
#  'https://www.gsmarena.com/apple-phones-48.php',
#  'https://www.gsmarena.com/huawei-phones-58.php',
#  'https://www.gsmarena.com/nokia-phones-1.php',
#  'https://www.gsmarena.com/sony-phones-7.php',
#  'https://www.gsmarena.com/lg-phones-20.php',
#  'https://www.gsmarena.com/htc-phones-45.php',
#  'https://www.gsmarena.com/motorola-phones-4.php',
#  'https://www.gsmarena.com/lenovo-phones-73.php',
#  'https://www.gsmarena.com/xiaomi-phones-80.php',
#  'https://www.gsmarena.com/google-phones-107.php',
#  'https://www.gsmarena.com/honor-phones-121.php',
#  'https://www.gsmarena.com/oppo-phones-82.php',
#  'https://www.gsmarena.com/realme-phones-118.php',
#  'https://www.gsmarena.com/oneplus-phones-95.php',
#  'https://www.gsmarena.com/vivo-phones-98.php',
#  'https://www.gsmarena.com/meizu-phones-74.php',
#  'https://www.gsmarena.com/blackberry-phones-36.php',
#  'https://www.gsmarena.com/asus-phones-46.php',
# ...

# %% [markdown]
# ### Extracting links of phones from each brand

# %%
specifications = ['Name','Network Technology', 'Network 2G bands', 'Network 3G bands', 'Network 4G bands', 'Network Speed', 
                  'Launch Announced', 'Launch Status', 'Body Dimensions', 'Body Weight', 'Body Build', 'Body SIM', 
                  'Display Type', 'Display Size', 'Display Resolution', 'Display Protection', 
                  'Platform OS', 'Platform Chipset', 'Platform CPU', 'Platform GPU', 
                  'Memory Card slot', 'Memory Internal', 'Memory \xa0', 
                  'Main Camera Dual', 'Main Camera Features', 'Main Camera Video', 
                  'Selfie camera Single', 'Selfie camera Features', 'Selfie camera Video', 
                  'Sound Loudspeaker ', 'Sound 3.5mm jack ', 
                  'Comms WLAN', 'Comms Bluetooth', 'Comms GPS', 'Comms NFC', 'Comms Infrared port', 'Comms Radio', 'Comms USB', 
                  'Features Sensors', 
                  'Battery Type', 'Battery Charging', 
                  'Misc Colors', 'Misc Models', 'Misc SAR', 'Misc Price', 
                  'Tests Performance']
import pandas as pd
temp = pd.DataFrame(columns=specifications)

# %%
# https://www.gsmarena.com/huawei-phones-58.php
import requests 
from bs4 import BeautifulSoup 
import csv

url = "https://www.gsmarena.com/huawei-phones-58.php"
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
pages = soup.find('div',attrs={'class':'nav-pages'})
brandpages = []
for a in pages.find_all('a'):
    page = a.get('href')
    fullLink = "https://www.gsmarena.com/"+page
    brandpages.append(fullLink)
brandpages

# %% [markdown]
# ### Extracting all the phones in a given page

# %%
import requests 
from bs4 import BeautifulSoup 
import csv
phones =[]
# for url in brandpages:
url = "https://www.gsmarena.com/oneplus-phones-95.php"
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
pages = soup.find('div',attrs={'class':'makers'})
for a in pages.find_all('a'):
    page = a.get('href')
    fullLink = "https://www.gsmarena.com/"+page
    phones.append(fullLink)
phones
# Out:
# ['https://www.gsmarena.com/oneplus_nord_n10_5g-10556.php',
#  'https://www.gsmarena.com/oneplus_nord_n100-10557.php',
#  'https://www.gsmarena.com/oneplus_8t-10420.php',
#  'https://www.gsmarena.com/oneplus_8t+_5g-10512.php',
#  'https://www.gsmarena.com/oneplus_nord-10289.php',
#  'https://www.gsmarena.com/oneplus_8_pro-9919.php',
#  'https://www.gsmarena.com/oneplus_8-10161.php',
#  'https://www.gsmarena.com/oneplus_8_5g_uw_(verizon)-10226.php',
#  'https://www.gsmarena.com/oneplus_8_5g_(t_mobile)-10229.php',
#  'https://www.gsmarena.com/oneplus_7t_pro_5g_mclaren-9928.php',
#  'https://www.gsmarena.com/oneplus_7t_pro-9872.php',
#  'https://www.gsmarena.com/oneplus_7t-9816.php',
#  'https://www.gsmarena.com/oneplus_7_pro_5g-9704.php',
#  'https://www.gsmarena.com/oneplus_7_pro-9689.php',
#  'https://www.gsmarena.com/oneplus_7-9623.php',
#  'https://www.gsmarena.com/oneplus_6t_mclaren-9469.php',
#  'https://www.gsmarena.com/oneplus_6t-9350.php',
# ...

# %%
newlis = ['https://www.gsmarena.com/oneplus_7_pro_5g-9704.php',
 'https://www.gsmarena.com/oneplus_7_pro-9689.php',
 'https://www.gsmarena.com/oneplus_7-9623.php',]

# %%
len(phones)
# Out:
# 306

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
l = []
count = 0
# for url in phones:
url = "https://www.gsmarena.com/oneplus-phones-95.php"
#if count>10: break
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
links = soup.find_all('div',attrs={'id':'specs-list'})
information = {}
info = {}
name = soup.find('h1',attrs={'class':'specs-phone-name-title'})
if name!=None:
    t = name.get_text()
    info['Name']=name.get_text()
for link in links:
    for table in link.find_all('table'):
        trs = table.find_all('tr')
        th = table.find('th').get_text()
        for td in trs:
            tdttl = td.find('td',attrs={'class':'ttl'})
            if tdttl != None:
                title = tdttl.get_text()
            tdnfo = td.find('td',attrs=
                            {'class':'nfo'})
            if tdnfo != None:
                infor = tdnfo.get_text()
            if infor!= None and title!=None:
                info[th+" "+title]=infor
l.append(info)
count += 1

# %%
len(l)
# Out:
# 11

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 
l = []
count = 0
for url in newlis:
    if count>10: break
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html5lib')
    links = soup.find_all('div',attrs={'id':'specs-list'})
    information = {}
    info = {}
    name = soup.find('h1',attrs={'class':'specs-phone-name-title'})
    if name!=None:
        t = name.get_text()
        info['Name']=name.get_text()
    for link in links:
        for table in link.find_all('table'):
            trs = table.find_all('tr')
            th = table.find('th').get_text()
            for td in trs:
                tdttl = td.find('td',attrs={'class':'ttl'})
                if tdttl != None:
                    title = tdttl.get_text()
                tdnfo = td.find('td',attrs=
                                {'class':'nfo'})
                if tdnfo != None:
                    infor = tdnfo.get_text()
                if infor!= None and title!=None:
                    info[th+" "+title]=infor
    print(info)                
    l.append(info)
    count += 1
# Out:
# {'Name': 'OnePlus 7 Pro 5G', 'Network Technology': 'GSM / HSPA / LTE / 5G', 'Network 2G bands': 'GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2', 'Network 3G bands': 'HSDPA 800 / 850 / 900 / 1700(AWS) / 1800 / 1900 / 2100 ', 'Network 4G bands': '1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 29, 32, 34, 38, 39, 40, 41, 66', 'Network 5G bands': '41 NSA/Sub6/mmWave', 'Network Speed': 'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/150 Mbps; 5G (2+ Gbps DL)', 'Launch Announced': '2019, May 14', 'Launch Status': 'Available. Released 2019, September 06', 'Body Dimensions': '162.6 x 75.9 x 8.8 mm (6.40 x 2.99 x 0.35 in)', 'Body Weight': '206 g (7.27 oz)', 'Body Build': 'Glass front (Gorilla Glass 5), glass back (Gorilla Glass 5), aluminum frame', 'Body SIM': 'Dual SIM (Nano-SIM, dual stand-by)', 'Display Type': 'Fluid AMOLED, 90Hz, HDR10+', 'Display Size': '6.67 inches, 109.2 cm2 (~88.5% screen-to-body ratio)', 'Display Resolution': '1440 x 3120 pixels, 19.5:9 ratio (~515 ppi density)'
# ...

# %%
len(l)
l
# Out:
# [{'Name': 'OnePlus 7 Pro 5G',
#   'Network Technology': 'GSM / HSPA / LTE / 5G',
#   'Network 2G bands': 'GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2',
#   'Network 3G bands': 'HSDPA 800 / 850 / 900 / 1700(AWS) / 1800 / 1900 / 2100 ',
#   'Network 4G bands': '1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 29, 32, 34, 38, 39, 40, 41, 66',
#   'Network 5G bands': '41 NSA/Sub6/mmWave',
#   'Network Speed': 'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/150 Mbps; 5G (2+ Gbps DL)',
#   'Launch Announced': '2019, May 14',
#   'Launch Status': 'Available. Released 2019, September 06',
#   'Body Dimensions': '162.6 x 75.9 x 8.8 mm (6.40 x 2.99 x 0.35 in)',
#   'Body Weight': '206 g (7.27 oz)',
#   'Body Build': 'Glass front (Gorilla Glass 5), glass back (Gorilla Glass 5), aluminum frame',
#   'Body SIM': 'Dual SIM (Nano-SIM, dual stand-by)',
#   'Display Type': 'Fluid AMOLED, 90Hz, HDR10+',
#   'Display Size': '6.67 inches, 109.2 cm2 (~88.5% screen-to-body ratio)',
# ...

# %%
temp = temp.append(l, ignore_index = True, sort = False)
# Out:
# c:\users\nagen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
temp
# Out:
#                          Name                   Network Technology  \
# 0         OnePlus Nord N10 5G         GSM / CDMA / HSPA / LTE / 5G
# 1           OnePlus Nord N100              GSM / CDMA / HSPA / LTE
# 2                  OnePlus 8T         GSM / CDMA / HSPA / LTE / 5G
# 3              OnePlus 8T+ 5G         GSM / CDMA / HSPA / LTE / 5G
# 4                OnePlus Nord                GSM / HSPA / LTE / 5G
# 5               OnePlus 8 Pro         GSM / CDMA / HSPA / LTE / 5G
# 6                   OnePlus 8         GSM / CDMA / HSPA / LTE / 5G
# 7   OnePlus 8 5G UW (Verizon)                GSM / HSPA / LTE / 5G
# 8     OnePlus 8 5G (T-Mobile)  GSM / CDMA / HSPA / EVDO / LTE / 5G
# 9   OnePlus 7T Pro 5G McLaren         GSM / CDMA / HSPA / LTE / 5G
# 10             OnePlus 7T Pro              GSM / CDMA / HSPA / LTE
# 11           OnePlus 7 Pro 5G                GSM / HSPA / LTE / 5G
# 12              OnePlus 7 Pro              GSM / CDMA / HSPA / LTE
# ...

# %%
def iter_pd(df):
    for val in df.columns:
        yield val
    for row in df.to_numpy():
        for val in row:
            if pd.isna(val):
                yield ""
            else:
                yield val

def pandas_to_sheets(pandas_df, sheet, clear = False):
    if clear:
        sheet.clear()
    (row, col) = pandas_df.shape
    cells = sheet.range("A1:{}".format(gspread.utils.rowcol_to_a1(row + 1, col)))
    for cell, val in zip(cells, iter_pd(pandas_df)):
        cell.value = val
    sheet.update_cells(cells)

scope =  ['https://www.googleapis.com/auth/spreadsheets', "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)
sheet = client.open("testing_sheets").sheet1    
pandas_to_sheets(temp,sheet)
